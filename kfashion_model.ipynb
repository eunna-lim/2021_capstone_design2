# %% [markdown]
# # K-Fashion 이미지 속성 분류기
#
# ### 본 코드는 K-Fashion 이미지의 속성 분류 모델을 개발 환경과 무관하게 실행시키고 확인할 수 있도록 해줍니다.

# %% [markdown]
# 코드를 실행하기 이전에 'kfashion_ai_model.zip' 파일을 본인의 구글 드라이브에 업로드해주시길 바랍니다.
#
# 또한 런타임 유형을 GPU로 설정하여 주십시오.

# %% [markdown]
# ### 드라이브 연결 및 모델 가져오기

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip gdrive/MyDrive/kfashion_ai_model.zip > /dev/null

# %%
cd /content/kfashion_ai_model
# Out:
# /content/kfashion_ai_model

# %% [markdown]
# ### 모델 실행 전 설치

# %%
# !pip install tqdm
# !pip install torchnet
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 676 kB 7.6 MB/s
# ...
#      |████████████████████████████████| 53 kB 1.4 MB/s
# ...
#   Created wheel for torchnet: filename=torchnet-0.0.4-py3-none-any.whl size=29741 sha256=fffda134bb4d3147fb2b12cd6ed7286ea528e6dd675d2e1408c97d2d74652b59
#   Stored in directory: /root/.cache/pip/wheels/93/17/b3/86db1d93e9dae198813aa79831b403e4844d67986cf93894b5
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655250 sha256=6a058b42ce475c796961aabdae62619bf4c67182a05e41418ef4594460ede31e
#   Stored in directory: /root/.cache/pip/wheels/2d/d1/9b/cde923274eac9cbb6ff0d8c7c72fe30a3da9095a38fd50bbf1
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5710 sha256=f0fbf3852a1d462fe3e11d4fa45cf2e86a2f99ffdf3bfebebc1e1d1d9d6ad4a4
#   Stored in directory: /root/.cache/pip/wheels/ac/5c/3a/a80e1c65880945c71fd833408cd1e9a8cb7e2f8f37620bb75b
# Successfully built torchnet visdom torchfile
# ...

# %% [markdown]
# ### 모델 실행

# %%
# !python test.py
# Out:
# Starting..
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 25 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# => loading checkpoint './checkpoint/kfashion_category/model_category_best.pth.tar'
# Test: 100% 856/856 [14:38<00:00,  1.03s/it]
# Top-3 recall: 0.9762
# [DONE] category time spent :882.8164
# => loading checkpoint './checkpoint/kfashion_detail/model_detail_best.pth.tar'
# Test: 100% 509/509 [08:42<00:00,  1.03s/it]
# Top-3 recall: 0.6379
# [DONE] detail time spent :1406.2235
# => loading checkpoint './checkpoint/kfashion_texture/model_texture_best.pth.tar'
# Test: 100% 820/820 [13:50<00:00,  1.01s/it]
# ...
